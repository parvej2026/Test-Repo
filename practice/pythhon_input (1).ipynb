# %%
print("hi")

# %%
a = int(input("enter your first number:"))
b = int(input("enter your secound number:"))

add = a + b
sub = a - b
mul = a * b
div = a / b

print("this is your add",add)
print("this is your sub",sub)
print("this is your mul",mul)
print("this is your div",div)

# %%
email = input("enter your email:")
password = input("enter your password: ")

actual_email ="entbappy73@gmail.com"
actual_password = "BAPPY@12345"

if email == actual_email and password ==actual_password:
  print("loging successfull")
elif email == actual_email and password !=  actual_password:
  print("incorrect passward, please try again")
  password = input("enter your password again: ")
  if password == actual_password:
    print("success")
  else:
      print("failed")

else:
  print("loging credentials")

# %%
tem = int(input("enter your current tempereture: "))

if tem >= 25:
  print(f"its {tem} hot outside")
elif tem >= 10 :
  print(f"its {tem} cool outside")
else:
  print(f"its {tem} too cold")
