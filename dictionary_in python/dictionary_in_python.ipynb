# %%
# create dictionary

# %%
d ={"name":"parvej","age":"29","gender":"male"}
print(d)

# %%
# with mixed keys

d1 ={(1,2,3):33,"name":"parvej"}
print(d1)

# %%
# 2d dictionary
d2 = {
    "name":"parvej",
    "age":29,
    "semester":7,
    "subject":{"math":100,"english":99,"bangla":98,"physics":97,}
}
print(d2)

# %%
# using sequence and dictionary function
d3 = dict([("name","parvej"),("age",29)])

print(d3)

# %%
d3["name"]

# %%
d3["age"]

# %%
d2["subject"]["math"]

# %%
# add key_value

# %%
d3["weight"] = 61

# %%
d3

# %%
d2["subject"]["history"]=99

# %%
d2

# %%
# editing key_value pair

# %%
d4={"name":"parvej","age":29,"gender":"male"}
d4["name"]="alex"

print(d4)

# %%
# remove key_value pair

# %%
d1 = {"name":"parvej","age":29,"gender":"male"}

# %%
#pop
d1.pop("age")

# %%
d1

# %%
# popitem
d1 = {"name":"parvej","age":29,"gender":"male"}
d1.popitem()
print(d1)

# %%
# del
d1 = {"name":"parvej","age":29,"gender":"male"}
del d1["name"]
print(d1)

# %%
#clear
d1 = {"name":"parvej","age":29,"gender":"male"}
d1.clear()
print(d1)

# %%
# loops with dictionary
d1 = {"name":"parvej","age":29,"gender":"male"}
for i in d1:
  print(i,d1[i])

# %%
for i in d1:
  print(f"{i} : {d1[i]}")

# %%
# dictionary method/function

# %%
#common method
d1 = {"name":"parvej","age":29,"gender":"male"}
print(len(d1))
print(max(d1))
print(min(d1))
print(sorted(d1))

# %%
 d1 = {"name":"parvej","age":29,"gender":"male"}
 print(d1.keys())

# %%
d1 = {"name":"parvej","age":29,"gender":"male"}
print(d1.values())

# %%
d1 = {"name":"parvej","age":29,"gender":"male"}
print(d1.items())

# %%
# update

d ={1:"a",2:"b"}
d1 = {2:"c",3:"d"}
d.update(d1)
print(d)

# %%
# 1.print 1st 10 number and their square
{i :i**2 for i in range(1,11)}
