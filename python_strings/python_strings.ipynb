# %%
print("ok")

# %%
# creating string

# %%
s = 'hello'
s = "hello"
s = """hello"""
s = '''hello'''
s = str('hello')
print(s)

# %%
a = 34
a = str(a)
print(type(a))

# %%
text = "my name is pasrvej"
print(text)

# %%
t = """ it's my bike
i love bike"""

print(t)

# %%
#accessing strings

# %%
a = "wellcome to python"

a[2]

# %%
a[10]

# %%
a[-4]

# %%
# string slicing

a = "wellcome to python"

# %%
a[0:10]

# %%
a[10:17]

# %%
a[0:]

# %%
a[0::2]

# %%
a[::-1]

# %%
# strings is immutable data type.it does not append and deleting.
# but if you want it can to concatination

# %%
a = "parvej"
b = "mosarrof"

c = a + b
print(c)

# %%
#strings method

# %% [markdown]
# common funtion / method
#
# len,
# max,
# min,
# sorted

# %%
a = "wellcome to python"

len(a)

# %%
max(a)

# %%
min(a)

# %%
sorted(a)

# %%
sorted(a, reverse =True)

# %%
a.capitalize()

# %%
d = a.upper()

# %%
a.lower()

# %%
z ="wellcome"
z.swapcase()

# %%
a.count("o")

# %%
a.index("p")

# %%
a.endswith("on")

# %%
a.startswith("we")

# %%
# format

name = "parvej"
gender = "male"

s = "my name is {} and i am {}"

# %%
s.format(name,gender)

# %% [markdown]
# f-strings

# %%
age = 29

s = f"my name is {name} and i am a {gender} my age is {age}"

print(s)

# %%
p = "my name is parvej"
p.split()

# %%
# join

s = ""

num = ["1","2","3","4"]
s = s.join(num)
print(s)

# %%
s = " "
word = ["my","name","is","parvej"]
s = s. join(word)
print(s)

# %%
# replace

s = "my name is parvej"
s.replace("parvej","mosarrof")
print(s)

# %%
# strip

s = "   my name is parvej        "
f = s.strip()
print(f)

# %%
# loops in strings

for i in "parvej":
  print(i)
