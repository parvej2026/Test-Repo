# %%
L =[22,65,56,"parvej",56,34,"bappy"]

# %%
L[2]

# %%
print(id(L))

# %%
print(id(L[3]))

# %%
#multipul item store in list

# %%
l = [2,3,4,"parvej",5.6,5+6j,True,[4,5,6]]

# %%
len(l)

# %%
l[7]

# %%
l[7][2]

# %%
print(list("hello"))

# %%
type([])

# %%
#accessing items from a list

# %%
l1=[[[2,3],[4,5]],[[8,9],[7,8]]]

# %%
l1[1][0][1]

# %%
l1[1][1][0]

# %%
l2 =[2,3,4,5,6,7,]

# %%
l2[0:4]

# %%
l2[:]

# %%
l2[::2]

# %%
#list method/function

# %%
#append

a =[1,3,4,6,8]
print (a)

# %%
a.append(5)

# %%
a1 =[2,3,5,6,7,]

a1.append([4,56,78,90])

print(a1)

# %%
a1.append(True)

# %%
a1

# %%
a

# %%
a.append(22)

# %%
a

# %%
b =[1,2,3,4,5]

# %%
b[4]= 100

# %%
b

# %%
# editing with slicing

b1 =[4,5,6,78,76,]
b1[1:3] = [12,34,56]

print(b1)

# %%
# extend
n = [3,4,5,6]
l = [11,23,44,54]

n.extend(l)
print(n)

# %%
# insert
s = [2,3,4,5,]
s.insert(1,23)
print(s)

# %%
# deleting items from a list

d = [2,3,4,5,6,]
del d[3]
print(d)

# %%
d = [2,3,4,5,6,]

del(d[0:2])
print(d)

# %%
d = [2,3,4,5,6,]
d.remove(3)
print(d)

# %%
d = [2,3,4,5,6,]
d.pop()
print(d)

# %%
d = [2,3,4,5,6,]
d.clear()
print(d)

# %%
d = [2,3,4,5,6,]

print(len(d))
print(max(d))
print(min(d))
print(sorted(d,reverse=True))

# %%
d = [2,3,4,5,6,4,4,4,4]
d.count(4)

# %%
d = [2,3,4,5,6,]
d.index(4)

# %%
d = [2,3,4,5,6,]
d.reverse()
print(d)

# %%
d = [2,3,4,5,6,]
d.sort()
print(d)

# %%
d = [2,3,4,5,6,]
d1 = d.copy()
print(d1)

# %%
# operation on list

# %%
# Arithmatic
a = [1,2,3,4,5]
b = [6,7,8,9,10]

a+b #concatination

# %%
a * 3 #repitition

# %%
# Membership
a = [1,2,3,4,5]
b = [6,7,8,9,10]

print(10 in b)

# %%
print(40 in a)

# %%
#loop
a1 = [4,5,6,76,54,]

for i in a1:
  print(i)

# %%
# add 1 to 10 number to a list
l = []
for i in range(1,11):
  l.append(i)
print(l)

# %%
LC = [i for i in range(1,11)]
print(LC)

# %%
# print all numbers divisibles by 5 in the range of 1 to 50

for i in range(1,51):
  if i % 5 == 0:
    print(i)

# %%
LC= [i for i in range(1,51) if i % 5 == 0]
print(LC)

# %%
a = [1,2,3,4,5]
b = [6,7,8,9,10]
list(zip(a,b))

# %%
student_roll =[1,2,3,4,5]
student_name =["parvej","kajol","sahed","riaz","raju"]
list(zip(student_roll,student_name))
