# %%
a = "my name is parvej"

# %%
len(a)

# %%
a[11]

# %%
a[-2]

# %%
a[11:]

# %%
a[-11:-15:-1]

# %%
a[-1::-1]

# %%
q = input("enter your text")
result = q[-1:-12:-1]
print(f"you are very nice:{result}")

# %%
name ="inception BD"

# %%
name.index("B")

# %%
s = name[10:]

# %%
s = " bd"

# %%
p = name[0:9]

# %%
p+s

# %%
name.upper()

# %%
name.lower()
