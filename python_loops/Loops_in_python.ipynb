# %%
print("ok")

# %%
for i in range(1,10):
  print(i)

# %%
for i in range(1,5):
  print("parvej")

# %%
a  = ("12345")
for i in a:
  print(a)

# %%
for i in range(1,10):
  print(i,"parvej")

# %%
for i in range(11,1,-1):
  print(i)

# %%
for i in range(1,11,2):
  print(i)

# %%
for i in [1,2,3,4]:
  print(i)

# %%
for i in "parvej":
  print(i)

# %%
# nested loops
for i in range(1,5):
  for j in range(1,5):
    print(i,j)

# %%
#loop coontrol statement

# %%
# Break
for i in range(1,11):
  if i == 5:
    print(i)
    break

# %%
name =["parvej","kajol","anamul","bappy","hridoy","ahsan habib"]

for i in name:
  if i == "hridoy":
    print(i)
    break

# %%
#continue
for i in range(1,10):
  if i == 5:
    continue
  print(i)

# %%
#pass
for i in range(1,10):
  pass
print("ok")

# %%
if 5==5:
  pass

# %%
#while loop

a = 0
while a < 10:
  a += 1
  print(a)

# %%
b = 0
while b < 10:
  b += 1
  print("parvej")

# %%
# program to print multiplication table

# %%
number = int(input("enter your number: "))
a = 1
while a < 11:
  print(number, "*", a, "=",number*a)
  a += 1

# %%
# while loops with else

a = 1

while a < 5:
  print(a)
  a += 1
else:
  print("programme executive")
